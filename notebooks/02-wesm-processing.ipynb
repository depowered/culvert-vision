# %%
from pathlib import Path
import geopandas

# %%
data_dir = Path("../data/")
source = data_dir / "external" / "usgs" / "WESM.gpkg.zip"
output = data_dir / "interim" / "mn_wesm.gpkg"

# %%
filter = "workunit LIKE 'MN%' AND (ql = 'QL 1' OR ql = 'QL 0')"
gdf: geopandas.GeoDataFrame = geopandas.read_file(filename=source, where=filter)

# %%
gdf.to_file(output, driver="GPKG")

# %%
gdf
# Out:
#                     workunit  workunit_id                            project
# 0         MN_LakeCounty_2018       187243             MN_LakeCounty_2018_C20  \
# 1        MN_RainyLake_2_2020       300017              MN_RainyLake_2020_B20
# 2        MN_RainyLake_1_2020       197389              MN_RainyLake_2020_B20
# 3      MN_SEDriftless_5_2021       228991           MN_SE_Driftless_2021_B21
# 4      MN_SEDriftless_1_2021       228969           MN_SE_Driftless_2021_B21
# 5     MN_LakeSuperior_1_2021       218907           MN_LakeSuperior_2021_B21
# 6      MN_SEDriftless_2_2021       222535           MN_SE_Driftless_2021_B21
# 7     MN_LakeSuperior_2_2021       228424           MN_LakeSuperior_2021_B21
# 8      MN_SEDriftless_3_2021       228972           MN_SE_Driftless_2021_B21
# 9   MN_MORiverBigSioux_1_B21       223443  MN_MissouriRiverBigSioux_2021_B21
# 10        MN_BeckerCo_1_2021       223404           MN_BeckerCounty_2021_D21
# ...

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   workunit            12 non-null     object
#  1   workunit_id         12 non-null     int64
#  2   project             12 non-null     object
#  3   project_id          12 non-null     int64
#  4   collect_start       12 non-null     object
#  5   collect_end         12 non-null     object
#  6   ql                  12 non-null     object
#  7   spec                12 non-null     object
#  8   p_method            12 non-null     object
#  9   dem_gsd_meters      12 non-null     float64
#  10  horiz_crs           12 non-null     object
#  11  vert_crs            12 non-null     object
#  12  geoid               12 non-null     object
#  13  lpc_pub_date        12 non-null     object
#  14  lpc_category        12 non-null     object
# ...

# %%
gdf.at[3, "sourcedem_link"]
# Out:
# 'http://prd-tnm.s3.amazonaws.com/index.html?prefix=StagedProducts/Elevation/OPR/Projects/MN_SE_Driftless_2021_B21/MN_SEDriftless_5_2021'
